# %%
import requests #for data collection
import pandas as pd

# %%
url = "https://v6.exchangerate-api.com/v6/27a7736bc968b92000f698a3/latest/USD"

#making request
response = requests.get(url)
data = response.json()

data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1747861201,
#  'time_last_update_utc': 'Wed, 21 May 2025 21:00:01 +0000',
#  'time_next_update_unix': 1747864801,
#  'time_next_update_utc': 'Wed, 21 May 2025 22:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 70.08265268,
#   'ALL': 86.76406858,
#   'AMD': 384.96589472,
#   'ANG': 1.79,
#   'AOA': 922.33866562,
#   'ARS': 1142.0,
#   'AUD': 1.55310193,
#   'AWG': 1.79,
#   'AZN': 1.69975864,
#   'BAM': 1.72665698,
#   'BBD': 2.0,
#   'BDT': 121.78831721,
#   'BGN': 1.7267847,
#   'BHD': 0.376,
#   'BIF': 2979.53631216,
#   'BMD': 1.0,
#   'BND': 1.29022112,
#   'BOB': 6.93653251,
#   'BRL': 5.66820231,
#   'BSD': 1.0,
#   'BTN': 85.62203018,
#   'BWP': 13.5075389,
#   'BYN': 3.04005066,
#   'BZD': 2.0,
#   'CAD': 1.38625598,
#   'CDF': 2891.56596805,
#   'CHF': 0.82515554,
#   'CLP': 943.77613017,
#   'CNY': 7.20353197,
#   'COP': 4184.99174113,
#   'CRC': 507.63390083,
#   'CUP': 24.0,
#   'CVE': 97.3447754,
#   'CZK': 21.98649495,
#   'DJF': 177.721,
#   'DKK': 6.58343556,
#   'DOP': 59.05514461,
#   'DZD': 132.85183879,
#   'EGP': 49.85819026,
#   'ERN': 15.0,
#   'ETB': 134.06002976,
#   'EUR': 0.88272483,
#   'FJD': 2.26545642,
#   'FKP': 0.74517897,
#   'FOK': 6.58353685,
#   'GBP': 0.7451873,
#   'GEL': 2.73907773,
#   'GGP': 0.74517897,
#   'GHS': 12.00975197,
#   'GIP': 0.74517897,
#   'GMD': 72.80277073,
#   'GNF': 8695.74941981,
#   'GTQ': 7.68828349,
#   'GYD': 210.20838272,
#   'HKD': 7.83159644,
#   'HNL': 26.06351954,
#   'HRK': 6.65165021,
#   'HTG': 131.03779643,
#   'HUF': 355.56473412,
#   'IDR': 16372.75894184,
#   'ILS': 3.550432,
#   'IMP': 0.74517897,
#   'INR': 85.62213176,
#   'IQD': 1312.54645348,
#   'IRR': 42071.42843704,
#   'ISK': 127.75095813,
#   'JEP': 0.74517897,
#   'JMD': 158.97100991,
#   'JOD': 0.709,
#   'JPY': 143.71016333,
#   'KES': 129.16489114,
#   'KGS': 87.44425311,
#   'KHR': 4004.68346959,
#   'KID': 1.55313238,
#   'KMF': 434.32177142,
#   'KRW': 1379.62860185,
#   'KWD': 0.30701218,
#   'KYD': 0.833333,
#   'KZT': 510.93748095,
#   'LAK': 21755.39021306,
#   'LBP': 89500.0,
#   'LKR': 299.7230169,
#   'LRD': 200.45991392,
#   'LSL': 17.94129677,
#   'LYD': 5.49112053,
#   'MAD': 9.22266436,
#   'MDL': 17.36685526,
#   'MGA': 4505.56011448,
#   'MKD': 54.55378985,
#   'MMK': 2103.19417122,
#   'MNT': 3602.86942731,
#   'MOP': 8.06652179,
#   'MRU': 39.89928041,
#   'MUR': 45.63145749,
#   'MVR': 15.48271989,
#   'MWK': 1741.64050142,
#   'MXN': 19.32994682,
#   'MYR': 4.27380508,
#   'MZN': 63.93492691,
#   'NAD': 17.94129677,
#   'NGN': 1586.21151261,
#   'NIO': 36.87022678,
#   'NOK': 10.16188238,
#   'NPR': 136.99524829,
#   'NZD': 1.68258497,
#   'OMR': 0.384497,
#   'PAB': 1.0,
#   'PEN': 3.69385519,
#   'PGK': 4.16563619,
#   'PHP': 55.65586195,
#   'PKR': 282.46621816,
#   'PLN': 3.74492027,
#   'PYG': 8022.73223954,
#   'QAR': 3.64,
#   'RON': 4.47586318,
#   'RSD': 103.45237088,
#   'RUB': 80.38555705,
#   'RWF': 1442.83678621,
#   'SAR': 3.75,
#   'SBD': 8.55619293,
#   'SCR': 14.21207631,
#   'SDG': 552.83413599,
#   'SEK': 9.56885352,
#   'SGD': 1.29013452,
#   'SHP': 0.74517897,
#   'SLE': 22.82072269,
#   'SLL': 22820.72270504,
#   'SOS': 572.35012014,
#   'SRD': 36.69906209,
#   'SSP': 4556.89063172,
#   'STN': 21.62922956,
#   'SYP': 12956.07413545,
#   'SZL': 17.94129677,
#   'THB': 32.73043631,
#   'TJS': 10.33807915,
#   'TMT': 3.5058817,
#   'TND': 2.99220579,
#   'TOP': 2.36715412,
#   'TRY': 38.85637521,
#   'TTD': 6.80782379,
#   'TVD': 1.55313238,
#   'TWD': 29.93788109,
#   'TZS': 2688.6800609,
#   'UAH': 41.43790181,
#   'UGX': 3656.56313338,
#   'UYU': 41.7351346,
#   'UZS': 12914.07609671,
#   'VES': 94.9652,
#   'VND': 25997.42168394,
#   'VUV': 121.15265374,
#   'WST': 2.69217877,
#   'XAF': 579.09569522,
#   'XCD': 2.7,
#   'XCG': 1.79,
#   'XDR': 0.73648733,
#   'XOF': 579.09569522,
#   'XPF': 105.34935598,
#   'YER': 244.30178498,
#   'ZAR': 17.94226982,
#   'ZMW': 27.21040711,
#   'ZWL': 26.8853}}

# %%
url_hist = "https://v6.exchangerate-api.com/v6/YOUR-API-KEY/history/USD/YEAR/MONTH/DAY"

# %%
from pandas import json_normalize

data_clean = json_normalize(data['conversion_rates'])

colnames = data_clean.columns

# %%
data_long = pd.melt(data_clean, value_vars = colnames, var_name = "Currency", value_name = "ExRates")

data_long
# Out:
#     Currency     ExRates
# 0        USD    1.000000
# 1        AED    3.672500
# 2        AFN   70.082653
# 3        ALL   86.764069
# 4        AMD  384.965895
# ..       ...         ...
# 158      XPF  105.349356
# 159      YER  244.301785
# 160      ZAR   17.942270
# 161      ZMW   27.210407
# 162      ZWL   26.885300
#
# [163 rows x 2 columns]

# %%
from datetime import datetime, timedelta

API_KEY = "27a7736bc968b92000f698a3"

# Start and end dates
start_date = datetime(2021, 1, 1)
end_date = datetime.today()

# To store all long format days
all_days = []

#Loop over each day starting from 2021
curr_date = start_date
while curr_date <= end_date:
    year = curr_date.year
    month = curr_date.month
    day = curr_date.day
    
    # Build URL
    url = f"https://v6.exchangerate-api.com/v6/{API_KEY}/history/USD/{year}/{month:02d}/{day:02d}"
    
    # Request from API and check status 
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        
        if "conversion_rates" in data:
            data_clean = json_normalize(data["conversion_rates"])
            data_long = pd.melt(
                data_clean, 
                value_vars=data_clean.columns, 
                var_name="Currency", 
                value_name="ExRate"
            )
            data_long["Date"] = curr_date.strftime("%Y-%m-%d")
            all_days.append(data_long)
        else:
            print(f"No conversion_rates on {curr_date}")
    else:
        print(f"Failed on {curr_date}: {response.status_code}")

    # Go to next day
    curr_date += timedelta(days=1)

# Combine all data
df_all = pd.concat(all_days, ignore_index=True)

# Preview
print(df_all.head())
# Out:
#   Currency      ExRate        Date
# 0      USD    1.000000  2021-01-01
# 1      AED    3.672500  2021-01-01
# 2      AFN   78.167102  2021-01-01
# 3      ALL  100.791577  2021-01-01
# 4      AMD  522.686556  2021-01-01

# %%
# null_counts = df_all.isnull().sxum()
# null_counts

# df_all.to_csv("ex_rate_all.csv", index = False)
df_all = pd.read_csv("ex_rate_all.csv")

# %%
codes_names = pd.read_csv("currency_codes_and_names.csv")

# %%
df_all = pd.merge(left = df_all, right = codes_names, how = "left", on = "Currency")
df_all['Date'] = pd.to_datetime(forex_df['Date'])
df_all = df_all[["Currency", "Currency Name", "Date", "ExRate"]]

# %%
df_all.to_csv("ex_rate_all.csv", index = False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_eur = df_all[df_all["Currency"] == "EUR"].copy()

df_eur["Date"] = pd.to_datetime(df_eur["Date"])

plt.figure(figsize = (12,6))
sns.lineplot(data=df_eur, x="Date", y="ExRate")
plt.title("USD to EUR Exchange Rate Over Time")
plt.ylabel("EUR per USD")
plt.xlabel("Date")
plt.tight_layout()
plt.show()

# %%
df_sle = df_all[df_all["Currency"] == "SLL"].copy()

df_eur["Date"] = pd.to_datetime(df_eur["Date"])

plt.figure(figsize = (12,6))
sns.lineplot(data=df_eur, x="Date", y="ExRate")
plt.title("USD to SLE Exchange Rate Over Time")
plt.ylabel("USD to SLL")
plt.xlabel("Date")
plt.tight_layout()
plt.show()

# %%
df_sle = df_all[df_all["Currency"] == "SLE"].copy()

df_eur["Date"] = pd.to_datetime(df_eur["Date"])

plt.figure(figsize = (12,6))
sns.lineplot(data=df_eur, x="Date", y="ExRate")
plt.title("USD to SLE Exchange Rate Over Time")
plt.ylabel("USD to SLE")
plt.xlabel("Date")
plt.tight_layout()
plt.show()

# %%
#Creating Percent Change/Return Variables

df_all = df_all.sort_values(["Currency", "Date"])

df_all["DlyReturn"] = df_all.groupby("Currency")["ExRate"].pct_change()

df_all["DlyReturn"] *= 100

top5 = df_all.sort_values(by="DlyReturn", key=lambda x: x.abs(), ascending = False).head(5)

top5_down = df_all.sort_values(by="DlyReturn", ascending=True).head(5)

print(top5)
print(top5_down)
# Out:
#        Currency      ExRate        Date   DlyReturn
# 198657      ZWL     13.4097  2024-05-16         inf
# 185942      LBP  89500.0000  2024-02-28  496.666667
# 125030      LBP   8253.7500  2023-02-17  447.512438
# 229275      ZWL     25.2906  2024-11-21  378.562643
# 227979      ZWL     25.4834  2024-11-13  363.747702
#        Currency     ExRate        Date   DlyReturn
# 198333      ZWL   0.000000  2024-05-14 -100.000000
# 45108       VES   4.159131  2021-10-09  -99.999593
# 192663      ZWL  13.561600  2024-04-09  -99.949731
# 228951      ZWL   5.284200  2024-11-19  -79.100286
# 227817      ZWL   5.495100  2024-11-12  -78.525790

# %%
df_zwl = df_all[df_all["Currency"] == "ZWL"].copy()

df_zwl["Date"] = pd.to_datetime(df_zwl["Date"])

plt.figure(figsize = (12,6))
sns.lineplot(data=df_zwl, x="Date", y="ExRate")
plt.title("USD to ZWL Exchange Rate Over Time")
plt.ylabel("ZWL per USD")
plt.xlabel("Date")
plt.tight_layout()
plt.show()
